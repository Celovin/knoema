# %% [markdown]
# # 50-Agent Village Analysis
#
# Loads the deterministic Phase 19 artifacts and displays core metrics.

# %%
import json
from pathlib import Path

root = Path('experiments/50_agent_village/results')
metrics = json.loads((root / 'metrics.json').read_text(encoding='utf-8'))
metrics['agent_count'], metrics['tick_count'], metrics['action_count']

# %%
metrics['action_mix']

# %%
metrics['reproducibility']
